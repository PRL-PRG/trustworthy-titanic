# %%
import pandas as pd
import numpy as np
import json
import os
from collections import Counter
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import seaborn as sns
import re
from sklearn.metrics import accuracy_score
import pickle
import plotly.express as px

# %matplotlib inline

# %%
data = pd.read_csv('titanic.csv')

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
test = pd.read_csv('test.csv')

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
list(test.columns)
# Out:
# ['PassengerId',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
names = {}

for c in list(test.columns):
    names[c] = c.lower()

# %%
names
# Out:
# {'PassengerId': 'passengerid',
#  'Pclass': 'pclass',
#  'Name': 'name',
#  'Sex': 'sex',
#  'Age': 'age',
#  'SibSp': 'sibsp',
#  'Parch': 'parch',
#  'Ticket': 'ticket',
#  'Fare': 'fare',
#  'Cabin': 'cabin',
#  'Embarked': 'embarked'}

# %%
test_ren = test.rename(columns=names)

# %%
test_ren.pop('passengerid')
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
# 5       897
# 6       898
# 7       899
# 8       900
# 9       901
# 10      902
# 11      903
# 12      904
# 13      905
# 14      906
# 15      907
# 16      908
# 17      909
# 18      910
# 19      911
# 20      912
# 21      913
# 22      914
# 23      915
# 24      916
# 25      917
# 26      918
# 27      919
# 28      920
# 29      921
#        ...
# 388    1280
# 389    1281
# 390    1282
# 391    1283
# 392    1284
# 393    1285
# 394    1286
# 395    1287
# 396    1288
# 397    1289
# 398    1290
# 399    1291
# 400    1292
# 401    1293
# 402    1294
# 403    1295
# 404    1296
# 405    1297
# 406    1298
# 407    1299
# 408    1300
# 409    1301
# 410    1302
# 411    1303
# 412    1304
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: passengerid, Length: 418, dtype: int64

# %%
data_trunc = data[['pclass',
                   'name',
                   'sex',
                   'age',
                   'sibsp',
                   'parch',
                   'ticket',
                   'fare',
                   'cabin',
                   'embarked',
                   'survived'
                  ]]

# %%
data_trunc.head()
data_trunc.to_csv('data_titanic.csv')

# %%
test_ren.head()
test_ren.to_csv('test_titanic.csv')

# %%
for i in range(3):

    print(data.iloc[i, 0:2])
# Out:
# pclass      1
# survived    1
# Name: 0, dtype: object
# pclass      1
# survived    1
# Name: 1, dtype: object
# pclass      1
# survived    0
# Name: 2, dtype: object

# %%
sur = {}

for i, r in test_ren[['name', 'age']].iterrows():

    for index, row in data_trunc[['name', 'age', 'survived']].iterrows():
        
        if list(r.values) == list(row[:-1].values):
            print(i)
            print(row[-1])
            sur[i] = row[-1]
        #else:
         #   print(list(r.values))
# Out:
# 0
# 0
# 1
# 1
# 2
# 0
# 3
# 0
# 4
# 1
# 5
# 1
# 6
# 0
# 7
# 1
# 8
# 1
# 9
# 0
# 11
# 0
# 12
# 1
# 13
# 0
# 14
# 1
# 15
# 1
# 16
# 0
# 17
# 0
# 18
# 0
# 20
# 0
# 21
# 1
# 23
# 1
# 24
# 1
# 25
# 0
# 26
# 1
# 27
# 0
# 28
# 0
# 30
# 0
# 31
# 0
# 32
# 1
# 34
# 1
# 37
# 0
# 38
# 1
# 40
# 1
# 42
# 0
# 43
# 0
# 44
# 1
# 45
# 0
# 46
# 1
# 48
# 1
# 50
# 0
# 51
# 0
# 53
# 1
# 55
# 0
# 56
# 0
# 57
# 1
# 59
# 1
# 60
# 0
# 61
# 0
# 62
# 0
# 63
# 1
# 64
# 1
# 66
# 0
# 67
# 0
# 68
# 1
# 69
# 1
# 70
# 1
# 71
# 0
# 72
# 0
# 73
# 0
# 74
# 1
# 75
# 0
# 77
# 1
# 78
# 0
# 79
# 0
# 80
# 0
# 81
# 0
# 82
# 0
# 86
# 0
# 87
# 1
# 89
# 1
# 90
# 1
# 92
# 1
# 94
# 0
# 95
# 1
# 96
# 1
# 97
# 0
# 98
# 0
# 99
# 0
# 100
# 1
# 101
# 0
# 103
# 1
# 105
# 0
# 106
# 1
# 109
# 0
# 110
# 0
# 112
# 0
# 113
# 0
# 114
# 0
# 115
# 0
# 117
# 1
# 118
# 0
# 119
# 0
# 120
# 1
# 122
# 1
# 123
# 0
# 125
# 1
# 126
# 0
# 128
# 0
# 129
# 0
# 130
# 0
# 131
# 1
# 134
# 0
# 135
# 0
# 136
# 0
# 137
# 0
# 138
# 1
# 139
# 0
# 140
# 0
# 141
# ...

# %%
for i, r in test_ren[:5].iterrows():
    print(list(r.values))
# Out:
# [3, 'Kelly, Mr. James', 'male', 34.5, 0, 0, '330911', 7.8292, nan, 'Q']
# [3, 'Wilkes, Mrs. James (Ellen Needs)', 'female', 47.0, 1, 0, '363272', 7.0, nan, 'S']
# [2, 'Myles, Mr. Thomas Francis', 'male', 62.0, 0, 0, '240276', 9.6875, nan, 'Q']
# [3, 'Wirz, Mr. Albert', 'male', 27.0, 0, 0, '315154', 8.6625, nan, 'S']
# [3, 'Hirvonen, Mrs. Alexander (Helga E Lindqvist)', 'female', 22.0, 1, 1, '3101298', 12.2875, nan, 'S']

# %%
len(sur)
# Out:
# 318

# %%
result = pd.merge(data_trunc, test_ren, on=['name'])

# %%
result = result[['name', 'survived']]

# %%
names_flat = []
for n in data_trunc['name']:
    names_flat.append(n.lower().replace(" ", ""))
    
data_trunc['names_flat'] = names_flat
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
data_trunc.head()
# Out:
#    pclass                                             name     sex    age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.00
# 1       1                   Allison, Master. Hudson Trevor    male   0.92
# 2       1                     Allison, Miss. Helen Loraine  female   2.00
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
#
#    sibsp  parch  ticket      fare    cabin embarked  survived  \
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0
#
#                                  names_flat
# 0                allen,miss.elisabethwalton
# 1               allison,master.hudsontrevor
# ...

# %%
names_flat = []
for n in test_ren['name']:
    names_flat.append(n.lower().replace(" ", ""))
    
test_ren['names_flat'] = names_flat

# %%
test_ren.head()
# Out:
#    pclass                                          name     sex   age  sibsp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
#
#    parch   ticket     fare cabin embarked  \
# 0      0   330911   7.8292   NaN        Q
# 1      0   363272   7.0000   NaN        S
# 2      0   240276   9.6875   NaN        Q
# 3      0   315154   8.6625   NaN        S
# 4      1  3101298  12.2875   NaN        S
#
#                                 names_flat
# 0                           kelly,mr.james
# 1             wilkes,mrs.james(ellenneeds)
# 2                   myles,mr.thomasfrancis
# 3                           wirz,mr.albert
# ...

# %%
result
# Out:
#                                                   name  survived
# 0                 Allison, Mr. Hudson Joshua Creighton         0
# 1                               Astor, Col. John Jacob         0
# 2                                 Beattie, Mr. Thomson         0
# 3                                    Bird, Miss. Ellen         1
# 4                                  Birnbaum, Mr. Jakob         0
# 5                              Bonnell, Miss. Caroline         1
# 6                             Borebank, Mr. John James         0
# 7                             Bowen, Miss. Grace Scott         1
# 8                              Brady, Mr. John Bertram         0
# 9                                   Brandeis, Mr. Emil         0
# 10      Brown, Mrs. John Murray (Caroline Lane Lamson)         1
# 11     Bucknell, Mrs. William Robert (Emma Eliza Ward)         1
# 12    Candee, Mrs. Edward (Helen Churchill Hungerford)         1
# ...

# %%
t = test['Name'][0]

# %%
result.loc[result['name'] == t][:1]['survived'].values[0]
# Out:
# 0

# %%
resnames = result.name.values

# %%
testnames = test.Name.values

# %%
sur = []

for name in test['Name']:
    
    if name in resnames:
        
        sur.append(result.loc[result['name'] == name][:1]['survived'].values[0])
        
    else:
        
        sur.append(0)

# %%
len(sur)
# Out:
# 418

# %%
cheat = pd.read_csv('cheater.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-0c5009b9272a> in <module>
# ----> 1 cheat = pd.read_csv('cheater.csv', index=False)
#
# TypeError: parser_f() got an unexpected keyword argument 'index'

# %%
cheat['Survived'] = sur

# %%
cheat.to_csv('cheater_3.csv')

# %%
files = []
import os
for root, dirs, files in os.walk("./r"):
    for file in files:
        if file.endswith(".r"):
             files.append(os.path.join(root, file))

# %%
files[:10]
