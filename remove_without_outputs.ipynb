# %%
import os
import pandas as pd
import numpy as np
import shutil

# %%
df = pd.read_csv('417NamesAccuracies.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              names  accuracies
# 0           0  prabhulingayya-titanic-prediction-using-logist...       0.746
# 1           1  erskumars-titanic-survival-eda-and-survival-ra...       0.749
# 2           2  paulocressoni-titanic-using-stepwise-linear-re...       0.756
# 3           3      abhayjindal-exploring-survival-on-the-titanic       0.744
# 4           4           jonmak-identify-travel-groups-in-titanic       0.739

# %%
names = df.names

# %%
len(names)
# Out:
# 418

# %%
ds = next(os.walk('./r/kernels'))

# %%
ds = []
for root, dirs, filenames in os.walk('./r/kernels'):
    for d in dirs:
        ds.append(d)
    break

# %%
len(ds)
# Out:
# 418

# %%
for d in ds:
    if d in names.values:
        pass
    else:
        print('remove')
        shutil.rmtree('./r/kernels/'+d)
# Out:
# remove
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-54-ef5803541f13> in <module>
#       4     else:
#       5         print('remove')
# ----> 6         shutil.rmtree('./r/kernels/'+d)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/shutil.py in rmtree(path, ignore_errors, onerror)
#     511             # can't continue even if onerror hook returns
#     512             return
# --> 513         return _rmtree_unsafe(path, onerror)
#     514
#     515 # Allow introspection of whether or not the hardening against symlink
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/shutil.py in _rmtree_unsafe(path, onerror)
#     372             entries = list(scandir_it)
#     373     except OSError:
# --> 374         onerror(os.scandir, path, sys.exc_info())
#     375         entries = []
#     376     for entry in entries:
#
# ...

# %%
i
# Out:
# 418

# %%
names.values[0]
# Out:
# 'prabhulingayya-titanic-prediction-using-logistic-regression'

# %%
i = 0
for root, dirs, filenames in os.walk('./r/kernels'):
    for n in filenames:
        if n == '.RData':
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
for d in os.listdir('./r/kernels'):
    os.remove('./r/kernels/'+d+'/script/.RData') if os.path.exists('./r/kernels/'+d+'/script/.RData') else None

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-a40782a4d316> in <module>
#       1 mypath = './r/kernels'
# ----> 2 onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
#
# NameError: name 'listdir' is not defined
